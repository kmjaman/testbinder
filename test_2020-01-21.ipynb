# %%
# %matplotlib inline
import matplotlib.pyplot as plt
#import netCDF4
import xarray as xr

# %%
d1 = xr.open_dataset('/home/kjaman/Downloads/metop/adaptor.mars.internal-1579621171.4533846-2821-19-39e83339-7e20-4b4b-922b-76832b68957e.nc')
d1
# Out:
# <xarray.Dataset>
# Dimensions:    (latitude: 721, longitude: 1440, time: 24)
# Coordinates:
#   * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.25 359.5 359.75
#   * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#   * time       (time) datetime64[ns] 2019-11-20 ... 2019-11-20T23:00:00
# Data variables:
#     skt        (time, latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2020-01-21 15:39:34 GMT by grib_to_netcdf-2.15.0: /opt/ecmw...

# %%
d1 = xr.open_dataset('/data/june_17.nc')
d1
# Out:
# <xarray.Dataset>
# Dimensions:    (latitude: 721, longitude: 1440, time: 24)
# Coordinates:
#   * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.25 359.5 359.75
#   * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#   * time       (time) datetime64[ns] 2019-06-17 ... 2019-06-17T23:00:00
# Data variables:
#     skt        (time, latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2020-01-23 01:01:40 GMT by grib_to_netcdf-2.16.0: /opt/ecmw...

# %%
d1.skt[0].plot();

# %%
d1.skt[12].plot();
